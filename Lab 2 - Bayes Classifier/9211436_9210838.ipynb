# %% [markdown]
# ## Student Information
#
# Please enter the names and IDs of the two students below:
#
# 1. **Name**: Youssef mohamed abdelkareem hagag
#    **ID**: `9211436`
#
# 2. **Name**: kareem samy fawzy elsayed
#    **ID**: `9210838`

# %% [markdown]
# ## Students Instructions
#
# Welcome to this learning module! As you embark on this journey, please keep the following in mind:
#
# - Clearly state your personal information where indicated.
# - Read the requirment carefully and refer to your lecture to understand any unclear concepts.
# - Hints are provided to guide you in one of the right direction but all ways lead to Rome.
# - **Keep the answers of the Essay questions in code cells for more clarity.**
#
# Remember, adhering to these guidelines is crucial for your success and will help you maximize your learning experience. Let's make the most out of this opportunity together!

# %% [markdown]
# # Bayesian Classifier
# In this lab, you will implement and assess the performance of the Bayesian Classifier.

# %%
#### always keep all your imports in the first cell ####
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import csv
import math

# %matplotlib qt

# %% [markdown]
# ## Requirement
#
# In this requirement, you will build the Bayesian Classifier and test its performance.
#
# You are provided with a data file **data1.csv** containing list of points and their corresponding classes. The format of the data files is shown in the table below.
#
# | |Class|Feature 1|Feature 1|
# |-|-|-|-|
# |Point#1|1|0.271633|-2.93224|
# |Point#2|1|7.020786|-1.98966|
# |Point#3|1|2.901827|-0.91291|
#
#
# You are also provided with a test data file **test_data.csv**. The file contains test points that are unlabelled (i.e. the class to which they belong is unknown).

# %%
# TODO [1] : Read the file 'data1.csv' into the variable data.
# data contains the training data together with labelled classes.
def read_data(file_name):
    data = []
    file = open(file_name, "r")
    data = list(csv.reader(file, delimiter=',',quoting = csv.QUOTE_NONNUMERIC,))
    file.close()
    return data

# %%
def read_test_data():
    
    # TODO [2.A]: Read the file 'test_data.csv' into the variable test_data
    # test_data contains the unlabelled test class.
    ## HINT: Do you need to cast the data you read from the file?
    test_data = []
    test_data = read_data('test_data.csv')
    # TODO [2.B]: Read the file 'test_data_true.csv' into the variable test_data_true
    # test_data_true contains the actual classes of the test instances, which you will compare
    # against your predicted classes.
    ## HINT: Do you need to cast the data you read from the file?
    test_data_true = []
    test_data_true = read_data('test_data_true.csv')
    return test_data, test_data_true

# %% [markdown]
# ### Machine Learning Terminlology
# Machine learning problems use common termonology (names and notiations) to refer to certain things. It is useful to use this termonology throughout your code to make it readable.
#
# | | |
# |:-|:--- |
# |$M$:|A scalar; represents the number of training points in the training set.|
# |$K$:|A scalar; represents the number of test points in the test set.|
# |$N$:|A scalar; represents the number of features of training set/test set (dimensionality of data).|
# |$X$:|A numpy array of shape $(M \times N)$ containing the training data **without** its labels, where $M$ is the number of training points and $N$ is the number of features in the dataset (or dimensionality of features). <br/> Each element in $X$ is a tuple $(X_1, X_2, \dots, X_N)$ where $N$ is the number of features in the dataset.|
# |$X_{test}$:| A numpy array of shape $(K \times N)$ containing the test data, where $K$ is the number of test points and $N$ is the number of features in the dataset (or dimensionality of features). <br/> Each element in $X_{test}$ is a tuple $(X_1, X_2, \dots, X_N)$ where $N$ is the number of features in the dataset. <br/> The number of columns in $X_{test}$ is equal to the number of columns in $X$ (because they have the same number of features). However, the number of rows in $X_{test}$ is different to the number of rows in $X$.|
# |**$Y$:| A numpy array of shape $(M \times 1)$ containing the labels of the training data. Each row in $Y$ corresponds to the label of the training point in $X$.<br/> For example, $Y[j]$ corresponds to the label of the training point $X[j]$ where $0<=j<M$.|

# %%
# TODO [3]: Fill the values of M, K, N, X, XTest, and Y respectively.
# Do not fill them manually (i.e. do not set N = 3). They should be generic for any input file.  
training_data = read_data('data1.csv')
test_data, test_data_true = read_test_data()

numClasses = 3 
M = len(training_data)
N = len(test_data[0])
K = len(test_data)
X = np.array(training_data)[:,1:3]
X_Test = np.array(test_data)
Y = np.array(training_data)[:,0:1]

# %%
# TODO [4]: Draw a scatter plot for traning data, where each class is coloured by the colour corresponding 
#           to its index in the colors array.
# Class 1 should be coloured in red, Class 2 should be coloured in green, and Class 3 should be coloured in blue.
# Hint: We have done a similar plot in the previous lab. What operation do we need to select training data 
#       belonging to a certain class?

colors = ['r', 'g', 'b', 'c', 'y']
c1 = np.array([X[i]for i in range(0,M) if(Y[i]==1.0) ] )
c2 = np.array([X[i]for i in range(0,M) if(Y[i]==2.0) ] )
c3 = np.array([X[i]for i in range(0,M) if(Y[i]==3.0) ] )
fig = plt.figure()
axis = fig.add_subplot(111)
axis.set_title('training Data')
axis.set_xlabel('Feature x.')
axis.set_ylabel('Feature y.')
axis.scatter(c1[:, 0], c1[:,1], c=colors[0],label="Class1 Points")
axis.scatter(c2[:, 0], c2[:,1], c=colors[1],label="Class2 Points")
axis.scatter(c3[:, 0], c3[:,1], c=colors[2],label="Class3 Points")
handles, labels = axis.get_legend_handles_labels()
unique = list(set(labels))
handles = [handles[labels.index(u)] for u in unique]
labels = [labels[labels.index(u)] for u in unique]
axis.legend(handles, labels)
plt.show()

# %%
## What do you notice about the plot? (Write everything you can think of)
'''
    Your Answer: there are 3 classes in the data and class 1 is the most dense class.
    The features used are good but not great since they separated the classes pretty well, 
    but there are still some overlapping points (error) between the 3 classes.
'''
# Out:
# '\n    Your Answer: there are 3 classes in the data and class 1 is the most dense class.\n    The features used are good but not great since they separated the classes pretty well, \n    but there are still some overlapping points (error) between the 3 classes.\n'

# %% [markdown]
# ### Bayesian Classifier
# The Bayesian Classifier calculates the probability of the test point belonging to each class, then the class with highest probability is assigned to the test point.
#
# Classification of $x_{test}$ = $argmax_{i} P\big(C_i|x_{test}\big)$ = $argmax_{i} P(x|C_i) * P(C_i)$
#
# * $P(C_i|x_{test})$: Posterior probability
# * $P(x|C_i)$: Class-conditional probability (or distribution)
# * $P(C_i)$: Class apriori probability
#
# **Note that** $P(C_i|x_{test}) \neq P(x_{test}|C_i) * P(C_i)$. Instead,  $P(C_i|x_{test}) = \frac{P(x_{test}|C_i) * P(C_i)}{P(x_{test})}$. However, when we compare multiple classes, the denominator $P(x_{test})$ is independent of the class $i$ and can be regarded as normalizing factor.
#
# **We start by** computing statistical parameters about each class from the data.
#
# For each class, we are interested in **three** parameters that will be used for calculating the Gaussian class-conditional distribution and the posterior probability.
#
# These parameters are:
#
# |||
# |:-|:-|
# |**Class Apriori Probability: ($P_C$)**| A scalar; the probability of class occurence (how frequent this class appears in the training data)|
# |**Class Mean: ($\mu$)**| A vector of shape $(N \times 1)$, it is the expected value (mean) calculated from the training points of each class.|
# |**Class Covariance Matrix: ($\Sigma$)**| A square symmetric matrix of shape $(N \times N)$ representing the covariances between all the feature calculated from the training points of the class. <br/> For example: Matrix element $\sigma^2_{12}$ is the covariance between the 1st and the 2nd features|

# %%
pClasses = [] # A list of size (numClasses, 1) containing the a priori probabilities of each class in the training set.

estimate_means = [] # A numpy array of size (numClasses, N) containing the mean points of each class in the training set. 
                    # HINT: USE NP.MEAN

estimate_covariances = [] # A numpy array of size (numClasses, N, N) containing the covariance matrices of each class in the training set.
                          # HINT: USE NP.COV (Pay attenention for what it takes as an argument)
                             
for classIndex in range(numClasses):
    # TODO [5]: Estimate the parameters of the Gaussian distributions of the given classes.
    # Fill pClasses, estimate_means, and estimate_covariances in this part 
    # Your code should be vectorized WITHOUT USING A SINGLE FOR LOOP.
    pClasses.append(float(len([Y[i] for i in range(0,M) if(Y[i]==classIndex+1)]))/float(M))
    estimate_means.append(np.mean([X[i] for i in range(0,M) if(Y[i]==classIndex+1)],axis=0))
    estimate_covariances.append(np.cov([X[i] for i in range(0,M) if(Y[i]==classIndex+1)],rowvar=False))

estimate_means = np.array(estimate_means)
estimate_covariances = np.array(estimate_covariances)

# %%
### Test your implementation ###
### DO NOT CHANGE THIS CODE ###
assert len(pClasses) == numClasses,\
        'Incorrect class apriori probability list, it should be of length {}'.format(len(pClasses))
assert np.sum(pClasses)==0.9999999999999999,\
        'Sum of apriori probabilities should be 1, found {}'.format(np.sum(pClasses))

assert estimate_means.shape == (numClasses, N),\
        'Incorrect estimated means, it should be of shape {}'.format((numClasses, N))
assert estimate_covariances.shape == (numClasses, N, N),\
        'Incorrect estimate covariance matrices, it should be of shape {}'.format((numClasses, N, N))

# %% [markdown]
# **The second step** in the classifier is to calculate the class-conditional density using the Gaussian destribution:
#
# $P(x|C_i) = \mathcal{N}(x; \mu_i, \Sigma_i) = \frac{1}{(2\pi)^{\frac{N}{2}}|\Sigma_i|^{\frac{1}{2}}} exp\big(\frac{-1}{2}(x-\mu_i)^T\Sigma^{-1}_{i}(x-\mu_i)\big)$

# %%
# TODO 6: Implement the multivariate normal gaussian distribution with parameters mu and sigma, and return the
#  value in prob.
def multivariate_normal_gaussian(X, mu, sigma):
    prob = (np.exp(-0.5 * np.matmul(np.matmul(np.transpose(X - mu), np.linalg.pinv(sigma)), (X - mu))))/(((2 * np.pi) ** (len(X)/2)) * (np.linalg.det(sigma)**0.5))
    return prob

# %%
### Test your implementation ###
### DO NOT CHANGE THIS CODE ###
np.random.seed(90)
assertion_x = np.random.rand(3).reshape(-1,1)
assertion_mu = np.random.rand(3).reshape(-1,1)
assertion_sigma = np.random.rand(9).reshape(3,3)
assertion_probability = multivariate_normal_gaussian(assertion_x, assertion_mu, assertion_sigma)[0][0]
assertion_probability = round(assertion_probability, 1)

assert assertion_probability == 7.8,\
    'Incorrect Gaussian Probability calculated'

# %% [markdown]
# **The final step** is to go for each test point, calculate its posterior probability against each class, then classify it to the class with the highest posterior probability.

# %%
# TODO [7]: Apply the Bayesian Classifier to predict the classes of the test points.
predicted_classes = [] # predicted_classes: A numpy array of size (K, 1) where K is the number of points in the test set. Every element in this array
                       # contains the predicted class of Bayes classifier for this test point.

for i in range(X_Test.shape[0]):
    print("For test point:", X_Test[i])
    classProbabilities = np.zeros(numClasses)
    # TODO [7.A]: Compute the probability that the test point X_Test[i] belongs to each class in numClasses.
    #  Fill the array classProbabilities accordingly.
    classProbabilities = [pClasses[classIndex]*multivariate_normal_gaussian(X_Test[i], estimate_means[classIndex], estimate_covariances[classIndex]) for classIndex in range(numClasses)]
    # TODO [7.B]: Find the prediction of the test point X_Test[i] and append it to the predicted_classes array.
    predicted_classes.append(np.argmax(classProbabilities)+1)

    print('Class Probabilities: ', classProbabilities)  # the first class is the left most in the scatter plot
    print("Predicted class is :", predicted_classes[i])
    print("******************************************************************************")
# Out:
# For test point: [10.70141426  3.87253627]
# Class Probabilities:  [2.6566737807921016e-12, 2.145998138559337e-17, 0.00024912853339846173]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.81831787 -5.00977814]
# Class Probabilities:  [0.015405760737064391, 1.5973383682827034e-10, 1.9460699680920356e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-3.57071936  9.96036181]
# Class Probabilities:  [7.934622592363082e-20, 0.0013655677721944278, 5.3871767324522506e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 4.94309043 -0.01539406]
# Class Probabilities:  [1.9576874883502187e-06, 1.9424640878211136e-08, 0.0056947043298988]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 4.26082551 -0.61349358]
# Class Probabilities:  [6.240623684661901e-06, 4.984234843571536e-08, 0.004727903123569658]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.98901139 16.86268221]
# Class Probabilities:  [4.487529471618056e-36, 0.00030928581960389015, 1.6626601153382354e-17]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.2796485  -3.38655342]
# Class Probabilities:  [0.0022165333282916527, 1.1651238531221453e-07, 8.338340785368965e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 2.60503344 -0.24206319]
# Class Probabilities:  [8.51743084465831e-05, 1.948348766976344e-06, 0.0022445832471048176]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.84312621 12.42130394]
# Class Probabilities:  [7.229095939046324e-20, 0.0052179188556710455, 1.7014222752753166e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-6.52253054 10.13668928]
# Class Probabilities:  [3.135139354054874e-25, 1.4032164593004367e-06, 7.461371722224792e-14]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 5.59472055 -4.37938379]
# Class Probabilities:  [2.8510653482130073e-09, 3.527567210789975e-12, 0.0011560224922952072]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.98596817 -0.73837508]
# Class Probabilities:  [0.0007994119398689418, 1.1935404139804295e-06, 4.43428960648133e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-2.23908496 13.21358765]
# Class Probabilities:  [7.417624168759112e-26, 0.003318401143535735, 3.77648975516494e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ -6.7789975 -11.0163502]
# Class Probabilities:  [0.0010887657680696023, 1.6072361500561333e-20, 2.071729209592499e-13]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 0.59545273 -0.41955489]
# Class Probabilities:  [0.0005737094492638214, 1.0697237880757143e-05, 0.0004582736652872604]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 8.36129364 -5.42102971]
# Class Probabilities:  [4.935896248878661e-15, 1.810831971050714e-17, 0.0002377542190140399]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.52848225 -7.42893531]
# Class Probabilities:  [0.001954016458835163, 5.80993827581129e-12, 1.2719465545205446e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.56086046 -9.03278997]
# Class Probabilities:  [0.0025996349214894164, 2.662671560118877e-15, 4.981200203028244e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 7.02188067 -0.93735269]
# Class Probabilities:  [6.301581164532657e-09, 6.999631707702914e-12, 0.005275358540514641]
# Predicted class is : 3
# ******************************************************************************
# For test point: [9.1509862  1.43750612]
# Class Probabilities:  [9.027802585223617e-11, 1.1168313719286798e-14, 0.0021748721991664537]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.71007022 10.6797775 ]
# Class Probabilities:  [6.145317516980107e-19, 0.009857683121262294, 2.901125239370798e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-4.76302456 -5.55297678]
# Class Probabilities:  [0.017158685041939303, 6.635924397420893e-12, 2.251746265420115e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.89883417 -5.39496672]
# Class Probabilities:  [0.016535114384012173, 6.68116261798833e-12, 1.9960031540837298e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [8.03379007 2.71590677]
# Class Probabilities:  [3.258908276250494e-09, 6.333804282916371e-12, 0.0022502437076902374]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.89215726 -2.59460822]
# Class Probabilities:  [0.00235266738409845, 1.5463857159150341e-09, 1.0711664721551241e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.11834647  4.91066223]
# Class Probabilities:  [1.0464964392362517e-10, 8.440174511214093e-05, 3.5471677818795715e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 6.45717699 -2.43934454]
# Class Probabilities:  [5.07994026987274e-09, 6.007802806561555e-12, 0.0036439004772789957]
# Predicted class is : 3
# ******************************************************************************
# For test point: [1.56547098 4.9207542 ]
# Class Probabilities:  [2.0785939019772935e-07, 0.001100589520451405, 8.50552242177895e-05]
# Predicted class is : 2
# ******************************************************************************
# For test point: [1.26265631 6.5794146 ]
# Class Probabilities:  [2.262555447436519e-09, 0.0034712036440505633, 1.014321872318936e-05]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 2.70832433 -3.11174424]
# Class Probabilities:  [3.0905401349848595e-05, 2.158688713584725e-08, 0.0011430619570948683]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ -9.10836917 -11.76552446]
# Class Probabilities:  [0.0008172060043418702, 1.1187177031899151e-25, 1.8703991986099129e-16]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.81726658 -5.3687788 ]
# Class Probabilities:  [0.01660470559577836, 8.627919762085121e-12, 2.3835700917882366e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.30975347  9.75343174]
# Class Probabilities:  [1.7267828108343264e-15, 0.014511625243768398, 1.241688630547264e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-7.58893623 -3.93631034]
# Class Probabilities:  [0.0006685070553293555, 2.697100334670417e-14, 1.6602312063720507e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-11.3843618 -12.1472865]
# Class Probabilities:  [0.00023618200012991944, 1.8151964055957756e-31, 1.4800134282578083e-19]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 6.15303864 -5.99521012]
# Class Probabilities:  [9.522185165278822e-12, 2.6586162485826236e-14, 0.0002494726887795205]
# Predicted class is : 3
# ******************************************************************************
# For test point: [0.88072334 9.72115039]
# Class Probabilities:  [2.0327838099372522e-14, 0.00873359713730402, 5.1405534243987954e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [1.3263618 8.7977202]
# Class Probabilities:  [1.5228194164947444e-12, 0.005762231200973784, 4.0790976905758253e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-4.70501109 11.56174259]
# Class Probabilities:  [1.238314540532546e-25, 0.00014519624278537925, 2.0306648513612804e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.12643357 -4.83616859]
# Class Probabilities:  [0.012854633703933926, 7.527133306455468e-10, 7.014380671101561e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 4.05674244 12.57155861]
# Class Probabilities:  [1.4265784946922967e-17, 2.982932587777611e-05, 1.478337374448761e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ -4.30106198 -10.6042502 ]
# Class Probabilities:  [0.00019659095586545706, 6.647386106461296e-17, 5.745182944787705e-11]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 5.11776496 -0.99143917]
# Class Probabilities:  [8.670643749280982e-07, 3.3129329054166406e-09, 0.00548755997642388]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 6.05493358 -5.87189841]
# Class Probabilities:  [1.9115529573359316e-11, 4.6946476646587015e-14, 0.0002873112122510754]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 3.74275953 -3.97527522]
# Class Probabilities:  [1.18595011453597e-06, 7.604860759085038e-10, 0.0010915816081827569]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.02170247 -5.57244813]
# Class Probabilities:  [0.016074925549210646, 3.283176936009311e-11, 8.506719961166536e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.27810154 -3.99998321]
# Class Probabilities:  [0.007217750058536886, 4.335200271560738e-11, 2.6063334326425137e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [5.80988364 3.43699512]
# Class Probabilities:  [1.8785769078793477e-07, 4.982769542133097e-08, 0.002013931531299385]
# Predicted class is : 3
# ******************************************************************************
# For test point: [8.6311676  1.76165524]
# Class Probabilities:  [5.205421726648224e-10, 1.833372311018973e-13, 0.0025904282910389803]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.73761305 -6.16978647]
# Class Probabilities:  [0.01720790103761944, 1.8256689363498866e-12, 1.3233510124324168e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [13.28411495 -2.28452888]
# Class Probabilities:  [1.671784400384636e-21, 2.462239132565424e-27, 2.6961165155997173e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.47775397 -0.10213091]
# Class Probabilities:  [0.0004276728426787696, 5.644248737885721e-06, 9.649610537617789e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.42758688 -7.1513932 ]
# Class Probabilities:  [0.011559107759705015, 3.9360795590211083e-13, 8.04615899410769e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-1.71805696 -8.49355483]
# Class Probabilities:  [0.00014174927289873886, 1.0290155602968209e-12, 9.198535845958221e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.07056432 13.27106731]
# Class Probabilities:  [3.481356252609652e-29, 0.0002954528806061533, 1.195756267383913e-14]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.82594718 -9.52426172]
# Class Probabilities:  [0.00015349274743390928, 1.973273674546806e-14, 4.000607101129548e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [10.2893587   1.35319816]
# Class Probabilities:  [1.9324661328811203e-12, 2.761848195336343e-17, 0.0010465073754434776]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.13419282  9.00152907]
# Class Probabilities:  [7.59348245415597e-15, 0.012840978477144598, 1.6268053186118143e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.29226867  7.97517886]
# Class Probabilities:  [2.7158059057836436e-12, 0.01176776032444527, 2.6504639506308903e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 9.46997908 -1.99299457]
# Class Probabilities:  [2.399590125968924e-13, 3.368456057906119e-17, 0.0013859912565484928]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.05416915 -2.47425901]
# Class Probabilities:  [0.003749468137839269, 4.6839885956146424e-07, 5.064449236697358e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 2.21553241 12.53863186]
# Class Probabilities:  [8.064895162697384e-19, 0.0010846799375158916, 4.748224903714526e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 8.85953786 -0.76518719]
# Class Probabilities:  [2.0677392044964184e-11, 3.601081998381039e-15, 0.002786567640008532]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 4.11560394 -2.51521659]
# Class Probabilities:  [2.5907837706579015e-06, 4.179460592165284e-09, 0.0027947137811378127]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-5.88633577 -7.73994173]
# Class Probabilities:  [0.013213847811293204, 2.0333511974037447e-15, 2.3317795461112715e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-1.79933965  5.31322455]
# Class Probabilities:  [2.534501440367737e-09, 0.0023558696537695515, 1.1369344021743341e-06]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 1.34271378 16.23529621]
# Class Probabilities:  [1.0145442427271234e-28, 0.0002782671132073702, 9.885742901052882e-15]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 1.55913997 10.48707791]
# Class Probabilities:  [2.6316664343453573e-15, 0.004431966473601098, 2.294964219695534e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.86122888  7.15903434]
# Class Probabilities:  [3.1543423919850494e-12, 0.005643401326321411, 1.0421933016962822e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.38794864  4.18558645]
# Class Probabilities:  [5.875057806439272e-09, 0.00017391108770578023, 2.673470902385813e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-9.52727338 -7.21208436]
# Class Probabilities:  [0.0013716870641350813, 4.095204637133005e-21, 7.19072075768496e-14]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.98956144 -7.5666012 ]
# Class Probabilities:  [0.011671831740528143, 3.7740475776548795e-14, 1.715464297607909e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-8.75405923 -5.30192282]
# Class Probabilities:  [0.0006951180092665531, 1.2564042032698933e-17, 3.553103515008223e-12]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-3.94621632 -6.88516599]
# Class Probabilities:  [0.010437170929576274, 2.0440203679314907e-12, 2.5580205659690475e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.31994442 -2.63044722]
# Class Probabilities:  [0.0016985700415051124, 4.896330873021923e-10, 4.538589703898497e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-9.36297948 -8.56822792]
# Class Probabilities:  [0.002893749216156582, 2.9280036592996973e-22, 2.0370086032730176e-14]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-3.81585174 -3.0905699 ]
# Class Probabilities:  [0.006885467120299896, 6.526269892711811e-09, 6.396170644938979e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [11.48384894 -2.13782697]
# Class Probabilities:  [2.434902659260625e-17, 3.8748082816050466e-22, 0.00024254460038551593]
# Predicted class is : 3
# ******************************************************************************
# For test point: [7.38337554 4.66707989]
# Class Probabilities:  [5.9091205170668666e-09, 3.8640541060923205e-10, 0.0007247942431902524]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.19811716 -3.20869437]
# Class Probabilities:  [0.008334371166756036, 1.5264231286583894e-08, 1.714442189394471e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.73664819 -5.64026754]
# Class Probabilities:  [0.01732015076497462, 5.857078009147083e-12, 2.189270692928364e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [5.16135146 8.11909452]
# Class Probabilities:  [1.3944979470102207e-10, 3.0907619592530467e-06, 1.1694681713186029e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.93192373 -7.90304636]
# Class Probabilities:  [0.009306919860912128, 1.915715731509909e-14, 1.2438535910231906e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 8.44663034 -1.10812617]
# Class Probabilities:  [5.2936948109912034e-11, 1.5333479015204443e-14, 0.0032014456891059384]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-10.41266737  -6.02755366]
# Class Probabilities:  [0.00010401310664487501, 7.284807448290504e-22, 1.9904891576887185e-14]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-10.55452885  -6.98597699]
# Class Probabilities:  [0.00024322923089075158, 3.534433813227621e-23, 5.089797511988222e-15]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.16708742 -4.41114641]
# Class Probabilities:  [0.0013115257910986215, 1.7394570222807695e-08, 4.934383850524814e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [6.83499316 3.0513492 ]
# Class Probabilities:  [4.1174082492331576e-08, 1.053742271786999e-09, 0.002481959390348788]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.3218284   8.03062152]
# Class Probabilities:  [2.087153956259256e-12, 0.01195541175767047, 2.3451614799260875e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.67262506 -3.63638033]
# Class Probabilities:  [0.009598114378195716, 1.4762877450563744e-08, 3.1531201178125722e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 1.23839346 15.50904654]
# Class Probabilities:  [6.66221639973382e-27, 0.0005801402651808075, 7.704637599231886e-14]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.85415463 -9.49083878]
# Class Probabilities:  [3.741273748945714e-06, 1.3922087618258962e-13, 5.589795258585548e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.57934474 14.05416562]
# Class Probabilities:  [1.4510309281802972e-25, 0.0041423133185478226, 5.084443204543658e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [1.08121918 9.02118593]
# Class Probabilities:  [4.603105589593586e-13, 0.007313673805900056, 2.2007418275021725e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.54545494 13.38470402]
# Class Probabilities:  [1.5299614115126866e-28, 0.0006660998520695731, 2.453892918960129e-14]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 0.25685021 12.98458764]
# Class Probabilities:  [8.231912684855899e-22, 0.00587566748021916, 2.267924253373198e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 8.49117921 -2.09111202]
# Class Probabilities:  [8.819851341421045e-12, 3.0976202749049813e-15, 0.0023167784704687094]
# Predicted class is : 3
# ******************************************************************************
# For test point: [9.6377611  2.59220877]
# Class Probabilities:  [4.1428917737071e-11, 2.7673902170290234e-15, 0.0010951192903682898]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 7.99632131 -0.81831291]
# Class Probabilities:  [3.5753104529885364e-10, 1.6313939026960625e-13, 0.004075598084408789]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.8066989  12.60496257]
# Class Probabilities:  [1.770287924385252e-18, 0.00040453047583175725, 6.410313025689499e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.14054117 13.99755821]
# Class Probabilities:  [8.294539464915059e-25, 0.004004780638713628, 1.0491822463046296e-12]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.0622924  -4.14345298]
# Class Probabilities:  [0.011845113747864126, 3.2731169846750806e-09, 1.267445630930749e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.73588097 -8.59503648]
# Class Probabilities:  [0.007979525099158438, 3.6893448712000116e-16, 9.999696467596018e-11]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.87691909 -8.51465367]
# Class Probabilities:  [0.005596437099868879, 4.7273708808750905e-15, 5.975951580116272e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 8.30461631 -2.42881748]
# Class Probabilities:  [9.383635261711897e-12, 4.270918783942635e-15, 0.0021851951126427354]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.92551153  9.38904848]
# Class Probabilities:  [1.8820597619528423e-16, 0.008795916990470226, 2.5560396440205195e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-8.06681967 -9.76445434]
# Class Probabilities:  [0.004580424955651826, 3.981469420174514e-21, 9.325254572478614e-14]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-8.24410989 -8.18831047]
# Class Probabilities:  [0.006576020316447988, 1.258599070561464e-19, 6.130903349261529e-13]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.37602904 -5.99069434]
# Class Probabilities:  [0.0170089603018679, 5.289232740973093e-13, 4.594761646167833e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.22386765 -4.85135398]
# Class Probabilities:  [1.2377367556821098e-06, 3.9039536860240594e-10, 0.00045210783575093047]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 1.55406083 -2.89224039]
# Class Probabilities:  [0.0002631464309204288, 1.2591928870800092e-07, 0.0005915375897877426]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.69049165 13.4044702 ]
# Class Probabilities:  [2.9530657762951264e-20, 0.0003345458217426918, 8.412773174634542e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.53571156 10.66187251]
# Class Probabilities:  [5.606743945453917e-20, 0.00506738546139897, 8.103664490789691e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 3.96782552 -4.31305255]
# Class Probabilities:  [4.0424678496617895e-07, 2.560971086982924e-10, 0.0009232843606062964]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.00081432  8.87275799]
# Class Probabilities:  [1.6751535295488086e-15, 0.007880955258556296, 5.6950265546166845e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-5.35696677 -3.77423836]
# Class Probabilities:  [0.005684975724555704, 5.4295805649885135e-11, 2.531655388261613e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 7.48811048 -3.16156655]
# Class Probabilities:  [4.563843792173515e-11, 4.0800681991033565e-14, 0.0020297943459701828]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ -6.06573364 -13.36721214]
# Class Probabilities:  [7.5396248834599545e-06, 1.2653105157754997e-22, 7.008642824862428e-15]
# Predicted class is : 1
# ******************************************************************************
# For test point: [5.1851141 2.6171304]
# Class Probabilities:  [8.141054324714777e-07, 1.675411914185267e-07, 0.002984115771483636]
# Predicted class is : 3
# ******************************************************************************
# For test point: [8.27828524 1.31354615]
# Class Probabilities:  [1.1056011240444043e-09, 5.838508263476781e-13, 0.003396866965314612]
# Predicted class is : 3
# ******************************************************************************
# For test point: [3.79242965 1.64031539]
# Class Probabilities:  [9.264938952172534e-06, 2.1073722611227075e-06, 0.0029802408328119126]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.138666   6.8602675]
# Class Probabilities:  [1.8944844636065816e-10, 0.0081296058707734, 1.5942846069457502e-06]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 5.78244942 -9.12198008]
# Class Probabilities:  [2.290888887353074e-15, 6.961104920376177e-17, 3.5290670056612615e-06]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 3.60435329 -5.38072375]
# Class Probabilities:  [1.824593068270445e-07, 6.818713688263793e-11, 0.00032880955029125023]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.85525938 -6.34543458]
# Class Probabilities:  [0.012787947805117699, 8.383269920688616e-12, 5.375716363686544e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [13.08621387  1.9348786 ]
# Class Probabilities:  [6.863764476691321e-17, 1.316159091445956e-24, 5.326488427319977e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.97701781 -8.26247269]
# Class Probabilities:  [0.003619463787336254, 6.909644321824056e-14, 4.267388809240071e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [0.3366769  1.22185752]
# Class Probabilities:  [0.00012974832106654017, 9.391614100217432e-05, 0.00027650624597656126]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-9.28532526 -9.4355402 ]
# Class Probabilities:  [0.0030695582838207456, 4.147274044995087e-23, 7.047579453924957e-15]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 1.66429005 11.01189494]
# Class Probabilities:  [3.2643773865173687e-16, 0.003604415544447234, 8.693230687350661e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.08966182 -1.69228564]
# Class Probabilities:  [0.0024583710483653196, 2.3806485019162992e-07, 3.3844673294112624e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 6.33789356 -2.66619436]
# Class Probabilities:  [5.2354170643395465e-09, 6.3107156460042474e-12, 0.0033239817483967666]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.56901228  5.51033591]
# Class Probabilities:  [7.946076354530254e-09, 0.004316032130022166, 4.890593571870474e-06]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 2.99286099 -4.68078563]
# Class Probabilities:  [2.840416213580427e-06, 8.010028755389927e-10, 0.00046732816117483344]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.80021733 11.42437424]
# Class Probabilities:  [9.511904891973444e-21, 0.008270631016659737, 5.189536109991988e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 1.16929961 -4.74585978]
# Class Probabilities:  [0.00012684218699174647, 5.789183720659084e-09, 0.00013451694637438099]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.15245262 14.77479741]
# Class Probabilities:  [1.9953860163931104e-26, 0.002196216913606397, 1.8285698976846338e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-11.57247905  -6.73922446]
# Class Probabilities:  [2.609705134550034e-05, 1.9602552037841901e-25, 3.0835196615357523e-16]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.60476346  4.55773513]
# Class Probabilities:  [9.050618923470396e-12, 2.0898415257707738e-06, 2.5184619712116706e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 7.91493717 -4.93203896]
# Class Probabilities:  [1.3700321437853362e-13, 3.1312881426968543e-16, 0.0004641533123132614]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-5.40280867 -4.97280708]
# Class Probabilities:  [0.012533712238901287, 4.379257915530152e-12, 1.0476622207004346e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [2.04297042 2.03014309]
# Class Probabilities:  [2.905209220698355e-05, 5.951005628433133e-05, 0.0009350607075718572]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ -6.21122011 -10.70086807]
# Class Probabilities:  [0.001160550189322237, 2.72947306678018e-19, 1.2436288205925902e-12]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.53064612 -8.83892725]
# Class Probabilities:  [0.006049433494048425, 3.5543110060576366e-16, 1.0589379671952978e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.30022088 11.20197432]
# Class Probabilities:  [1.7582319052214934e-15, 0.0002582823523752129, 2.0289478788550054e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 0.52678262 11.00539841]
# Class Probabilities:  [3.540099491880889e-17, 0.009649223422901445, 2.7912067972090663e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [6.2375991  2.80421505]
# Class Probabilities:  [1.3628102284679467e-07, 7.241595766690725e-09, 0.0029525784556778795]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-7.1883182  -1.89030168]
# Class Probabilities:  [4.096641930467937e-05, 5.033981703502969e-12, 9.196280663618183e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.60122702 15.01466265]
# Class Probabilities:  [3.547129050327402e-28, 0.002212599576773649, 3.512548356693719e-14]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.34641109 -4.86072033]
# Class Probabilities:  [0.0039175020263826224, 4.94832979115222e-09, 8.837097798444837e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 6.63822042 -5.45296469]
# Class Probabilities:  [6.031330378929413e-12, 1.5416968108778784e-14, 0.0004100655536228576]
# Predicted class is : 3
# ******************************************************************************
# For test point: [6.54807184 1.19913258]
# Class Probabilities:  [8.615011482613077e-08, 5.259933088213541e-10, 0.005312051032041125]
# Predicted class is : 3
# ******************************************************************************
# For test point: [11.7595198   0.33353443]
# Class Probabilities:  [1.4943742550405663e-15, 1.6935873875735563e-21, 0.00031124681465880997]
# Predicted class is : 3
# ******************************************************************************
# For test point: [10.04384705  3.3153199 ]
# Class Probabilities:  [1.6355239131686773e-11, 5.697092956326341e-16, 0.000578023895106788]
# Predicted class is : 3
# ******************************************************************************
# For test point: [3.72322077 2.89573292]
# Class Probabilities:  [3.5193781887303573e-06, 8.153144827513532e-06, 0.0016355041771444322]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.23412033 10.5086633 ]
# Class Probabilities:  [3.827761406257965e-22, 0.00042685752305139955, 5.076653265500911e-12]
# Predicted class is : 2
# ******************************************************************************
# For test point: [2.75812898 9.80988701]
# Class Probabilities:  [2.104004263779584e-13, 0.0008775424533267336, 2.215238010093477e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [5.71709878 0.05250004]
# Class Probabilities:  [3.885283180549972e-07, 2.232566416492246e-09, 0.006237038068363196]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.4383003  14.46253234]
# Class Probabilities:  [1.9424257962686662e-33, 8.08690626220749e-05, 2.3686724517047737e-16]
# Predicted class is : 2
# ******************************************************************************
# For test point: [10.31980548  5.65793048]
# Class Probabilities:  [6.53273158589027e-12, 4.738749310051262e-16, 7.504484042174388e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-10.37524372  -7.74958537]
# Class Probabilities:  [0.0006156136544314918, 1.3996355288923935e-23, 3.5529911411042546e-15]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.60020077 -5.42453553]
# Class Probabilities:  [0.016975135895495416, 1.2831254235339931e-11, 3.4145685280592504e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.20850522 -0.73094364]
# Class Probabilities:  [3.771936106801249e-05, 3.741777650001616e-07, 0.003071007270271432]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 8.67511969 -0.45766944]
# Class Probabilities:  [5.99089215006703e-11, 1.2660071511132157e-14, 0.0031861846198079588]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.84241029 -2.07200837]
# Class Probabilities:  [0.0038377926993863, 1.827376906783854e-07, 4.606070672768867e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [5.02815393 0.12504483]
# Class Probabilities:  [1.7103512286843286e-06, 1.834936231117664e-08, 0.005755573698962986]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 1.63527967 10.82193815]
# Class Probabilities:  [7.119981376544963e-16, 0.0038645519718391577, 1.2529343131491492e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [4.69546404 1.63793279]
# Class Probabilities:  [2.7287867516172714e-06, 2.4856753891405567e-07, 0.0040348503583109985]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.20495861 -8.54182529]
# Class Probabilities:  [0.003297871523266705, 2.1136383203227703e-14, 1.9391758512631547e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.85664823  8.27107861]
# Class Probabilities:  [1.780319383713387e-19, 7.4487177367929985e-06, 1.0708595632856547e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-5.43266395 -7.3131535 ]
# Class Probabilities:  [0.01460258895089039, 2.1370436013039046e-14, 9.887120039246287e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.43743782 10.57358038]
# Class Probabilities:  [2.4727092420178714e-14, 0.00022292219943853084, 7.928126186138154e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [4.51691079 1.90895905]
# Class Probabilities:  [3.1273806071773284e-06, 5.165563251178761e-07, 0.003492806482988393]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.95393725 -2.06290005]
# Class Probabilities:  [3.884412911703821e-05, 8.169471651995576e-08, 0.0020395098664899294]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.17022706 -4.71914956]
# Class Probabilities:  [0.008042413994533176, 3.296745233679132e-09, 3.248524478911234e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [6.87943361 0.56763302]
# Class Probabilities:  [3.094452806695545e-08, 7.836396510356969e-11, 0.005671041277605082]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 8.90155375 -2.49446135]
# Class Probabilities:  [8.285337940187547e-13, 2.5294069868515893e-16, 0.0015714990334051175]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.75309704 10.13350214]
# Class Probabilities:  [2.8220404379059024e-15, 0.009383134023542166, 2.061536635976344e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-6.83046209 -9.95463151]
# Class Probabilities:  [0.0036885814263262467, 2.768015265338736e-19, 1.2029671260684375e-12]
# Predicted class is : 1
# ******************************************************************************
# For test point: [7.48084666 2.21690041]
# Class Probabilities:  [1.1751524172503652e-08, 4.162539041127712e-11, 0.0033025622532710827]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.51484158 16.05856446]
# Class Probabilities:  [1.477447280264182e-36, 0.00012659216956869478, 1.3847217049897417e-17]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.29796106 -1.51960377]
# Class Probabilities:  [0.002557991000947355, 8.597382599210643e-07, 1.1950228903087177e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 1.04675075 14.39325425]
# Class Probabilities:  [2.8062734731348283e-24, 0.001579011889368945, 1.4468654870775998e-12]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.33223697 -7.63241344]
# Class Probabilities:  [0.0037432498693137175, 1.0836996280199325e-12, 2.875941726328068e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.38944943 -9.23325113]
# Class Probabilities:  [0.0017435024699788736, 2.331654500682552e-15, 4.970743692440527e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.74176393 -5.02512921]
# Class Probabilities:  [0.015408301062430423, 2.130302625767138e-11, 3.640445448551576e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-7.41004634 -5.5997003 ]
# Class Probabilities:  [0.004724799593414525, 1.6749725017211052e-15, 7.843347710249815e-11]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-8.09797276 -7.51282903]
# Class Probabilities:  [0.006664567974401082, 1.2687793420804065e-18, 2.0683744035185405e-12]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 1.65055    14.73266536]
# Class Probabilities:  [2.102332854559134e-24, 0.0006655268504080331, 1.0492598725835365e-12]
# Predicted class is : 2
# ******************************************************************************
# For test point: [1.15219027 3.63873026]
# Class Probabilities:  [2.773431318527351e-06, 0.0006361331286138847, 0.00017533422804688677]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.25543293  9.24132191]
# Class Probabilities:  [1.983833796737044e-15, 0.012590225317785511, 8.984025634437295e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.3701864  10.61688349]
# Class Probabilities:  [1.1904522108138332e-19, 0.005985172650044567, 1.167969533199074e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-11.26329666  -7.92344489]
# Class Probabilities:  [0.000170947561005733, 6.35565067763249e-26, 2.081207550384676e-16]
# Predicted class is : 1
# ******************************************************************************
# For test point: [1.37598504 5.76529642]
# Class Probabilities:  [2.3766274305667496e-08, 0.0021494474471052305, 2.982571457370658e-05]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.88140712 -3.02402962]
# Class Probabilities:  [0.006401773524991898, 6.494860024188154e-09, 5.872023436971126e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-3.66886091 -1.94857083]
# Class Probabilities:  [0.0025011208186333975, 6.095757626263705e-08, 1.2140893574681085e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 0.21817753 10.22511294]
# Class Probabilities:  [6.5025513804815255e-16, 0.012419564451216012, 9.521578216913068e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 3.01734447 -3.01633766]
# Class Probabilities:  [1.8020074306204426e-05, 1.5572769976032732e-08, 0.00141456157645836]
# Predicted class is : 3
# ******************************************************************************
# For test point: [2.45242039 2.18725534]
# Class Probabilities:  [1.940025298369115e-05, 4.0314770807296965e-05, 0.001162438727892831]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.81338366 -3.04810313]
# Class Probabilities:  [2.646008741892367e-05, 2.0490778568101305e-08, 0.001251314097516156]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.35226244  7.94145336]
# Class Probabilities:  [4.0825930951146256e-13, 0.009721114447244647, 6.868446104259391e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.32479122 -9.12757714]
# Class Probabilities:  [0.00013561454457372373, 1.0895343471372177e-13, 1.555927310340966e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [10.99032273 -0.46466519]
# Class Probabilities:  [9.092128288035819e-15, 6.899584490602257e-20, 0.0006284723321371947]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-7.52557256 -5.00051738]
# ...
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.06815545  9.53292586]
# Class Probabilities:  [1.4074274339301047e-19, 0.0005747020025682016, 4.770861627081679e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [7.34079799 3.06978894]
# Class Probabilities:  [1.4891447840760173e-08, 1.5193466548476244e-10, 0.0022607714628329156]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.64032058 12.0068455 ]
# Class Probabilities:  [6.505386829628698e-22, 0.00783804918508945, 1.7892739681837247e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [11.02141864 -0.12519999]
# Class Probabilities:  [1.4762663836513722e-14, 8.67245282482597e-20, 0.0006314744349147045]
# Predicted class is : 3
# ******************************************************************************
# For test point: [2.83660161 7.63741536]
# Class Probabilities:  [3.1070125710235473e-10, 0.0006276690134511886, 8.38597289224501e-06]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 0.55253392 -2.86889414]
# Class Probabilities:  [0.0010070949813695321, 2.504648172437541e-07, 0.0002524379689021469]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.97166844 -3.22481456]
# Class Probabilities:  [1.7317603334831604e-06, 1.7671857213188455e-09, 0.0018844027863689679]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.98490968 -4.84749576]
# Class Probabilities:  [0.012177717999272645, 9.109130601689227e-10, 8.698795923996065e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [9.10588756 1.58507517]
# Class Probabilities:  [1.154117087240125e-10, 1.611350443949826e-14, 0.0021473251797930193]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 4.99945013 -3.95313184]
# Class Probabilities:  [3.9156490996168464e-08, 4.1229996167349786e-11, 0.0015141056003294495]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 1.71883232 15.1537229 ]
# Class Probabilities:  [2.217385127814983e-25, 0.0004479172136114469, 3.4426135583004687e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.33163346  9.72288532]
# Class Probabilities:  [1.8856510128052107e-15, 0.014548480764947235, 1.2791170836601233e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [11.04296746  1.25113376]
# Class Probabilities:  [1.088156235717502e-13, 3.431469040459097e-19, 0.0005706433662749877]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.22009129  9.65386874]
# Class Probabilities:  [3.2434981858917716e-15, 0.014326933381485564, 1.6707604888527195e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.70876068  2.17594789]
# Class Probabilities:  [1.2198689429423714e-05, 0.00018207526841380005, 1.5320143516512902e-05]
# Predicted class is : 2
# ******************************************************************************
# For test point: [4.51045177 7.56673947]
# Class Probabilities:  [5.92316771584484e-10, 1.6815684391626674e-05, 2.162431369496108e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.29825485 13.66342044]
# Class Probabilities:  [1.3614027912944166e-25, 0.004623633944792828, 5.154957908360288e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-9.72864588 -6.0121161 ]
# Class Probabilities:  [0.00034210884822908494, 2.5784909884446693e-20, 1.4073337882444897e-13]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.48899942 17.98748437]
# Class Probabilities:  [7.507452298037807e-37, 0.00014080268084198735, 3.9390393020826524e-18]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.77337683  7.24172304]
# Class Probabilities:  [1.8284679399395454e-11, 0.009377850873792934, 4.2711781709297055e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.05007773 15.12157932]
# Class Probabilities:  [7.269110407494171e-31, 0.001264932676820857, 2.966906783796215e-15]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.79351842 -4.31693215]
# Class Probabilities:  [0.013374217615147744, 6.759720420722587e-10, 3.3683904837414274e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [7.23987052 0.84895898]
# Class Probabilities:  [1.423665208001464e-08, 2.7250938553212456e-11, 0.005112104526442457]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-7.30596448 -3.23156572]
# Class Probabilities:  [0.0003611965501099148, 3.0277671950182334e-13, 4.6177555043619825e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.28227684 -5.29628215]
# Class Probabilities:  [0.01488421600989669, 3.0736246735069336e-12, 1.028676579354454e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 7.84284999 -4.65776943]
# Class Probabilities:  [3.8158112924242137e-13, 7.052472478439478e-16, 0.0006091014581879772]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.36231452 14.65339584]
# Class Probabilities:  [4.713925711500333e-30, 0.0013576543716316398, 6.677067951091769e-15]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-5.11518005 -5.99608685]
# Class Probabilities:  [0.01748257600390261, 1.0464184283501756e-12, 7.633463217805266e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [8.61237327 4.48009751]
# Class Probabilities:  [6.027950904566587e-10, 1.6483064578081014e-12, 0.0005770058689749488]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.95457177 -2.6426557 ]
# Class Probabilities:  [0.000653670625664718, 3.010235072079138e-07, 0.0004024188454548316]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.91149048 -9.43001297]
# Class Probabilities:  [0.004240919364422762, 2.4080038201236677e-17, 1.991333681644778e-11]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.90520993  5.66899844]
# Class Probabilities:  [3.900702901432617e-14, 1.993348157082888e-06, 3.91989770970486e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-4.82381941  9.48699204]
# Class Probabilities:  [1.2402326549880353e-20, 0.00012358680138282812, 1.1499964265008003e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 3.51481518 -2.69629369]
# Class Probabilities:  [8.368842811174846e-06, 1.0878300234524687e-08, 0.002073781564341192]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 4.81850398 -1.42510573]
# Class Probabilities:  [1.2778032085247857e-06, 4.0166965132489615e-09, 0.0047875397671550916]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.32369809 -7.1393455 ]
# Class Probabilities:  [0.005706503634374245, 3.5539428612878417e-12, 5.359177763805264e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.46861438 -1.4433357 ]
# Class Probabilities:  [0.00024140027428737744, 2.4081863710280952e-09, 4.4098987220994876e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-1.98740359 -5.57716425]
# Class Probabilities:  [0.005011973890547037, 6.791022075607503e-10, 2.0441109486403077e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [11.65009927  4.93480248]
# Class Probabilities:  [1.7405043643851003e-13, 1.3235118812392517e-19, 4.773898607520007e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-5.29799896 -4.9997967 ]
# Class Probabilities:  [0.013206597938257385, 5.495263781495952e-12, 1.2648460096161572e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-8.39210413 -8.94948394]
# Class Probabilities:  [0.005651840709730547, 9.138265017383731e-21, 1.4662118138717434e-13]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 0.03147831 -1.78716335]
# Class Probabilities:  [0.0015683901839446531, 1.6862058196906424e-06, 0.00021804898466089173]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 7.24658383 -0.90643208]
# Class Probabilities:  [3.345870307465624e-09, 3.088942077963182e-12, 0.005049912296201443]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 3.56004924 -1.02757626]
# Class Probabilities:  [1.98925267684018e-05, 1.2756068535335365e-07, 0.0034876707170922072]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 7.36264317 -0.22355351]
# Class Probabilities:  [4.763994712152165e-09, 4.755013057049151e-12, 0.005273859357508577]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.87468243  1.68851414]
# Class Probabilities:  [3.0568912918602612e-06, 6.690816161743884e-06, 5.865366722728441e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.71271544 -9.47990792]
# Class Probabilities:  [2.331898568029306e-05, 8.150463970652307e-14, 2.0153891326530938e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-6.79673036 -6.33979581]
# Class Probabilities:  [0.011109347151143856, 2.948090702528745e-15, 1.6147361872284444e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [0.06008745 9.97311029]
# Class Probabilities:  [1.4333167852466665e-15, 0.013332602845178553, 1.2864986199618132e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-4.82746067 -3.56345126]
# Class Probabilities:  [0.006541871037338872, 3.123218354863872e-10, 8.016368938458128e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-7.90632459 -9.21895769]
# Class Probabilities:  [0.006213878175938802, 3.431149341179466e-20, 3.235269839268441e-13]
# Predicted class is : 1
# ******************************************************************************
# For test point: [7.36874346 0.62545597]
# Class Probabilities:  [8.950847691439043e-09, 1.2772899714660957e-11, 0.005113484155097246]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 8.22552188 -0.20662172]
# Class Probabilities:  [3.5527689610360975e-10, 1.3200588253258154e-13, 0.003973574301414799]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 1.20850538 -2.82403166]
# Class Probabilities:  [0.0004450331242242828, 1.874724166260482e-07, 0.0004626170604917871]
# Predicted class is : 3
# ******************************************************************************
# For test point: [3.21579751 2.94840046]
# Class Probabilities:  [4.9257490212552e-06, 2.3329099947085205e-05, 0.0012376849320221372]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.20729307 -5.44771275]
# Class Probabilities:  [0.006481768899102868, 7.12282663873491e-10, 1.6887438385337455e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.40036386 -5.32174925]
# Class Probabilities:  [0.014490623201785745, 2.1164909547746385e-12, 7.961263521320237e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 0.15531485 -4.12155615]
# Class Probabilities:  [0.0010178511378870201, 2.94580883345748e-08, 8.443743207834288e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [9.22382129 5.71360307]
# Class Probabilities:  [7.864965471041283e-11, 1.5910504688298803e-13, 0.00013996277527350104]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.63952042 -4.65786291]
# Class Probabilities:  [0.0020324430269027384, 1.010822274067118e-08, 2.4349454285547063e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [9.15705042 1.29990602]
# Class Probabilities:  [7.95674927524194e-11, 9.43749531040711e-15, 0.0022367203843962854]
# Predicted class is : 3
# ******************************************************************************
# For test point: [10.95944226  1.34437573]
# Class Probabilities:  [1.6757446849332174e-13, 6.141076314682344e-19, 0.0006037576343448332]
# Predicted class is : 3
# ******************************************************************************
# For test point: [12.70138697  4.8417071 ]
# Class Probabilities:  [5.1574283686859236e-15, 1.3333235021378507e-22, 1.6860535584042215e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [8.13412403 8.8823782 ]
# Class Probabilities:  [4.675452434151129e-12, 5.3349936795140034e-11, 3.3131625335489797e-06]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.02416693 11.64233379]
# Class Probabilities:  [1.4351563746771283e-21, 0.006751814612314028, 2.25681698957731e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [1.06908312 1.27293507]
# Class Probabilities:  [0.0001036823439182607, 6.785526132762673e-05, 0.0005545117380862103]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 9.66236602 -2.51130178]
# Class Probabilities:  [3.552715415436911e-14, 5.849995328951779e-18, 0.000969454761982333]
# Predicted class is : 3
# ******************************************************************************

# %%
# TODO [8]: Compute the accuracy of the generated Bayesian classifier 
# WITHOUT USING ANY FOR LOOPs.
accuracy = np.count_nonzero(np.asarray(test_data_true).reshape(-1) == np.asarray(predicted_classes).reshape(-1)) / np.asarray(test_data_true).shape[0]
print('Accuracy = ' + str(round(accuracy,4) * 100) + '%')
# Out:
# Accuracy = 95.56%

# %%
# TODO [9]: Generate a 3D-plot for the generated distributions. x-axis and y-axis represent the features of the data, 
#           where z-axis represent the Gaussian probability N at this point.

x = np.linspace(-10, 10, 300)
y = np.linspace(-10, 15, 300)
X, Y = np.meshgrid(x, y)
Z = np.zeros(X.shape)
for i in range(Z.shape[0]):
    for j in range(Z.shape[1]):
        # TODO [9]: Fill in the matrix Z which will represent the probability distribution of every point.
        # Z[i,j] represents the joint probability N(x,y) for x = i and y = j. 
        # We want to draw the gaussian probability N(x,y) for all points. 
        jointProp1 = multivariate_normal_gaussian(np.array((X[i,j],Y[i,j])), estimate_means[0], estimate_covariances[0]) * pClasses[0]
        jointProp2 = multivariate_normal_gaussian(np.array((X[i,j],Y[i,j])), estimate_means[1], estimate_covariances[1]) * pClasses[1]
        jointProp3 = multivariate_normal_gaussian(np.array((X[i,j],Y[i,j])), estimate_means[2], estimate_covariances[2]) * pClasses[2]
        Z[i, j] = max(jointProp1,jointProp2,jointProp3)

# Make a 3D plot, do not change code
fig = plt.figure()
# ax = fig.gca(projection='3d')
ax = fig.add_subplot(projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis', linewidth=0)
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')
plt.show()

# %%
# How can you judge your plot is correct?
'''
    Your Answer:
    by looking at the top view of the 3d plot and comparing it to the scatter plot previously drawn,
    we can notice the similarity between both, with all 3 classes being clearly separated,
    the position (x,y) of the 3 peaks corresponds to the estimated mean of the 3 classes, 
    while the height (z-axis) corresponds to the density of the points in the scatter plot 
    (the gaussian probability at that point), which means that the plot is consistent with the data.
'''
# Out:
# '\n    Your Answer:\n    by looking at the top view of the 3d plot and comparing it to the scatter plot previously drawn,\n    we can notice the similarity between both, with all 3 classes being clearly separated,\n    the position x,y \n    while the height (z-axis) corresponds to the density of the points in the scatter plot \n    (the gaussian probability at that point), which means that the plot is consistent with the data.\n'

# %% [markdown]
# ## Submission Instructions
#
# To ensure a smooth evaluation process, please follow these steps for submitting your work:
#
# 1. **Prepare Your Submission:** Alongside your main notebook, include any additional files that are necessary for running the notebook successfully. This might include data files, images, or supplementary scripts.
#
# 2. **Rename Your Files:** Before submission, please rename your notebook to reflect the IDs of the two students working on this project. The format should be `ID1_ID2`, where `ID1` and `ID2` are the student IDs. For example, if the student IDs are `9123456` and `9876543`, then your notebook should be named `9123456_9876543.ipynb`.
#
# 3. **Check for Completeness:** Ensure that all required tasks are completed and that the notebook runs from start to finish without errors. This step is crucial for a smooth evaluation.
#
# 4. **Submit Your Work:** Once everything is in order, submit your notebook and any additional files via the designated submission link on Google Classroom. Make sure you meet the submission deadline to avoid any late penalties.
#
# By following these instructions carefully, you help us in evaluating your work efficiently and fairly. If you encounter any difficulties or have questions about the submission process, please reach out as soon as possible.
#
# We look forward to seeing your completed projects and wish you the best of luck!
